# %% [markdown]
# # iteration in python
# 1. iteration means loop to work with wepeatative tasks or repeatative performances
# 2. python have 2 types of iterators
# 3.`for` loop
# 4. `while` loop
#
# ```python - fot loop
# for iter _varible in sequenve:
#     print("for is keyword to start the for loop")
#    print("iter_veriable is one type fo veriable to iterate data form sequence")
#    print("in is keyword to validate dequnce is present or not")
#    print("sequence is collection like range,list,tuple ,...etc")
# ```
#
# ```python - while loop
# while(condition):
#     print("while is keyword to start the iteration based on condition")
#     print("conditon is true executed inside statments")
# ```

# %% [markdown]
# #write a program to print 1 to 50

# %%
#write a program to iterate name using for loop
name="shivaji"
for char in name:
    print(char)
# Out:
# s
# h
# i
# v
# a
# j
# i

# %%
# write a program to find the even number in between 100 to 150 using for loop? 
for n in range(100,151):
   if (n%2==0):
       print(n,end=",")
# Out:
# 100,102,104,106,108,110,112,114,116,118,120,122,124,126,128,130,132,134,136,138,140,142,144,146,148,150,

# %%
# write a program to find the even number in between 100 to 150 using for loop? 
for n in range(100,151):
   if (n%2==1):
       print(n,end=",")
# Out:
# 101,103,105,107,109,111,113,115,117,119,121,123,125,127,129,131,133,135,137,139,141,143,145,147,149,

# %%
#write a prpgram ro find the vowels from string using for loop? 
name=str(input("please enter your name here:"))
for char in name:
    if(char in "aeiouAEIOU"):
        print(char)
# Out:
# please enter your name here: a

# %%
#write a prpgram ro find the vowels from string using for loop? 
name=str(input("please enter your name here:"))
for char in name:
    if(char not in "aeiouAEIOU"):
        print(char)
# Out:
# please enter your name here: ritheesh
# r
# t
# h
# s
# h

# %%
# write a progam to read name from list using for loop
name =["vikas","shivaji",'aditya',chandra'']
for n in name 
    print("my name is",n)

# %%
#1.write a program to find the sum of all numbers in between 1 to 100 using for loop?
#2.write a pragram to find the sum of all even number 1 to 50 using for loop?
#3.write a pragram to find the sum of all odd number 1 to 50 using for loop?
