# %%
#operators in python

##python have 6 types of operators
1.arithematic operators
2.assignment operators
3.comparision opertors
4.logical opertors
5.membership opertors
6.identity opertors
# Out:
#   Cell In[2], line 4
#     1.arithematic operators
#      ^
# SyntaxError: invalid decimal literal

# %%
#arithematic opertors- +,-,*,/,//,%
a=100
b=200
c=300
d=400
print(a+b)
print(b-d)
print(a*c)
print(b/a)
print(b//a)
print(d%b)
# Out:
# 300
# -200
# 30000
# 2.0
# 2
# 0

# %%
#assiment opertors-+=,-=,/=,//=,%=
a=10
a=a+10
print(a)
# Out:
# 20

# %%
a=10
a+=10
print(a)
# Out:
# 20

# %%
a=25
a-=50
print(a)

# %%
a=2
a*=6
print(a)
# Out:
# 12

# %%
a=5
a/=10
print(a)

# %%
a=100
a//=200
print(a)
# Out:
# 0

# %%
a=9
a%=900
print(a)
# Out:
# 9

# %%
#comparision opertors->,<,<=,>=,==,!+(return True or false)
a=5
b=10
c=10
d=20
print(a>b)
print(b<c)
print(b>=c)
print(b==c)
print(b!=d)
# Out:
# False
# False
# True
# True
# True

# %%
#logical opertors-and,or,not 
#and - this opertors checking all condition are true result is true rest cases failed
#or - this opertors check either one true true then result true rest cases faild 
a=10
b=20
c=20
d=60
print(a>b and b==c)
print(a<b and c<d)
print(a>b or b==c)
print(a>b or b!=c)
print(not a>b or b!=c)

# %%
#membership opertors - cheeking members are present in that sequence or 
name=["shaiva","vikas","divya","alok"]
print("alok" in name )
print("chandra" in names)
print("shaiva" not in names)
print("vikas" in names)

# %%
#identitity opertors -memory identification of value - is ,is not 
a=100
b=100
print (id(a))
print (id(b))
print (a is b)
# Out:
# 140733896437976
# 140733896437976
# True

# %%
a=10
b=10
print (id(a))
print (id(b))
print (a is b)
# Out:
# 140733896435096
# 140733896435096
# True
