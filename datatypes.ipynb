# %%
#data types in python 
1.python have 3 data types 
2.int(integer)
3.str(string)
4.flot(decimal)
# Out:
#   Cell In[9], line 2
#     1.python have 3 data types
#      ^
# SyntaxError: invalid decimal literal

# %%
name="shivaji123"
age=25
salary=1000.25
print(name)
print(age)
print(salary)
# Out:
# shivaji123
# 25
# 1000.25

# %%
data="120"
print(data)
# Out:
# 120

# %%
a=100
b=120
print(a+b)
# Out:
# 220

# %%
v1=100
v2=100.25
print(v1+v2)
# Out:
# 200.25
