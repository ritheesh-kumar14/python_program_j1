# %% [markdown]
# # conditional statements in python
# 1.python have 4 types of conditional statements
# 2.`if`statement
# 3.`elif`statement
# 4.`else`statement
# 5.`nested`statement
#
# ```python if
# if(condition):
#     statement
#     statement...
# ```
#
# ```python if,else
# if(condition):
#     statement
#     statement...
# else:
#     statement
#     statement...
# ```
#
# ```pyton if,elif,elese
# if(condition):
#     statement
# elif (condition)
#     statement
# else:
#    statement...
# ```

# %%
#write aprogram to find the givien number is even number
num=int(input("please enter number here:") )
if(num%2==0):
    print(num,"is even number")
# Out:
# please enter number here: 123

# %%
#write a program to find the given number is even is even number or odd numder 
number =int(input("please enter number here:"))
if (number%2==0):
  print(number,"is even number")
else:
    print(number,"is odd number")

# %%
#write a program to find the given number is positive or negitive or zero?k
number =int(input("please enter number here:"))
if (number%2==0)
   print(number,"is positive number")
else:
    print(number,"is negitive number")
else:
    print(number,"is zero number")
# Out:
#   Cell In[11], line 3
#     if (number%2==0)
#                     ^
# SyntaxError: expected ':'

# %%
n=int(input("enter number here:"))
if(n>0):
    print(n,"is positive")
elif(n<0):
     print(n,"is negitive")
eles:
     print(n,"is zero")

# %%
"""
write a program to find the student grades based in maeks 
1.if student maeks in between 100 to 80 then grade is A
2.if student maeks in between 79 to 60 then grade is B
3.if student maeks in between 59 to 40 then grade is c
4.if student maeks in between 39 to 25 then grade is d
5.if student maeks in between 24 to 0 then grade is fail
6.fi other then above marks expected output should be please enter correct marks!
"""
marks = int(input("enter student marks here :"))
if(marks>=80 and marks<=100):
    print(marks,"is A grade")
elif(marks>=60 and marks<=79):
    print(marks,"is B grade")
elif(marks>=40 and marks<=59):
     print(marks,"is C grade")
elif(marks>=25 and marks<=39):
     print(marks,"is D grade")
elif(marks>=0 and mark<=24):
     print(marks,"is fail grade")
else:
   print(marks,"is not crrect mark,please enter correct marks")
# Out:
# enter student marks here : 74
# 74 is B grade

# %%
#write a program to find the largest number from three numbers
#write a program to find the largest year or non leap year
#write a program to check login credentials using condition statements
# Program to find the largest among three numbers

# %% [markdown]
# ### Program to find the largest among three numbers
# # Demonstrates: if, elif, else statements
#
# a = float(input("Enter first number: "))
# b = float(input("Enter second number: "))
# c = float(input("Enter third number: "))
#
# if a > b and a > c:
#     print("The largest number is:", a)
# elif b > a and b > c:
#     print("The largest number is:", b)
# else:
#     print("The largest number is:", c)
# # Program to check whether a year is a leap year or not
# # Demonstrates: nested if statements
#
# year = int(input("Enter a year: "))
#
# if year % 4 == 0:
#     if year % 100 == 0:
#         if year % 400 == 0:
#             print(year, "is a leap year.")
#         else:
#             print(year, "is not a leap year.")
#     else:
#         print(year, "is a leap year.")
# else:
#     print(year, "is not a leap year.")
# # Program to check login credentials
# # Demonstrates: if and else statements
#
# username = input("Enter username: ")
# password = input("Enter password: ")
#
# if username == "admin":
#     if password == "1234":   # nested if example
#         print("Login successful!")
#     else:
#         print("Incorrect password.")
# else:
#     print("Invalid username.")
